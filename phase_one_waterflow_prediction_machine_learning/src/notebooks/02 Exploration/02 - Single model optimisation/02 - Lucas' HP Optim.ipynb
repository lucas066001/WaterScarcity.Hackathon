# %% [markdown]
# ## Goals: Hyper Parameter Optimisation of *QRF* model
#
# This notebook propose different methods of hyper parameter optimisation based on X-Validation :
# * Random Search
# * Genetic algorithm [Not yet included]
#
# # 1. Data Import and Setup
#
# Imports necessary libraries, sets up environment paths.

# %%
# Standard library imports
import os
import sys
import json

# Third-party imports
from functools import partial
import numpy as np
import pandas as pd
from quantile_forest import RandomForestQuantileRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectKBest, f_regression

# Append project root to sys.path for local imports
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', '..')))

# Local application imports
from src.utils.model import get_station_stats, custom_log_likelihood
from src.utils.SpatioTemporalSplit import SpatioTemporalSplit
from src.utils.custom_models import SnowIndexComputeTransformer

# %% [markdown]
# Defines constants :
# * INPUT_DIR must be the same as the one defined in *00 Preprocessing/Feature Engineering*.
# * MODEL_DIR is the directory where the exploration models will be saved.

# %%
INPUT_DIR = "../../../../data/input/"
MODEL_DIR = "../../../../models/exploration/"

SEED = 42 
ALPHA = 0.1
NUMBER_OF_WEEKS=4 

DATASET_TRANSFORMS = [
    "rm_gnv_st",
    "pca",
    "snow_index",
    # "oh_enc_date",
    "cyc_enc_date",
    "clust_index",
    "clust_hydro",
    # "scl_feat",
    "scl_feat_wl", # Scale all except waterflow lag
    "rm_wl", # remove custom generated water_flow_lag 3w & 4w ---> Need USE_CUSTOM_PREPROCESS = True
    "slct_ma", # keep only specific mobile average 2w or/and 3w or/and 4w ---> Need USE_CUSTOM_PREPROCESS = True
    "lag_slope" # add an indicator that is calculated between water_flow_lag 1w and 2w 
]

PCA_THRESHOLD = 0.98
N_CLUSTER = 4

DATASET_SPEC = "_".join(DATASET_TRANSFORMS)

if "pca" in DATASET_TRANSFORMS:
    DATASET_SPEC += f"_pct_{PCA_THRESHOLD}"

if "clust_index" in DATASET_TRANSFORMS:
    DATASET_SPEC += f"_geocl_{N_CLUSTER}"

if "clust_hydro" in DATASET_TRANSFORMS:
    DATASET_SPEC += f"_hydcl_{N_CLUSTER}"

DATASET_SPEC = "dataset_custom_20"

# columns to drop : target at different horizon, station_code, and features removed from Feature Selection
TO_DROP = ["water_flow_week1", "station_code", "water_flow_week2", "water_flow_week3", "water_flow_week4"]

# %% [markdown]
# # 2. Data Loading
# Load in the baseline datasets, create the directory to save models.

# %%
# load the dataset
ds_train = pd.read_csv(f"{INPUT_DIR}{DATASET_SPEC}.csv")
train_data = ds_train.copy()
train_data.reset_index(inplace=True)
train_data = train_data.loc[:, ~train_data.columns.duplicated()]
ds_train = ds_train.set_index("ObsDate")
cv_data = train_data.copy()

y_train = {}
for i in range(0, NUMBER_OF_WEEKS):
    y_train[i] = train_data[f"water_flow_week{i+1}"]

# %% [markdown]
# ### 3. Model preparation
#
# Compute station statistics (usefull for scalling)

# %% [markdown]
# Create a custom Pipeline to keep track of the station code

# %% [markdown]
# Initialisation of the log likelihood scorer

# %%
def inverted_log_likelihood(estimator, X, y_true, cv_data, station_stats, alpha=0.1):
    return -custom_log_likelihood(estimator, X, y_true, cv_data, station_stats, alpha=alpha)

# %% [markdown]
# Initialisation of the SpatioTemporal Splitter

# %%
cv = SpatioTemporalSplit(
    n_splits=10,
    date_col='ObsDate',
    station_col='station_code',
    temporal_frac=0.6,
    spatial_frac=0.6,
    random_state=42
)

# %% [markdown]
# Fill NaN to avoid kbestSelector error

# %%
cv_data.isna().sum()
# Out:
# index                            0
# ObsDate                          0
# precipitations_lag_1w_pca_1      0
# precipitations_lag_1w_pca_2      0
# precipitations_pca_1             0
# precipitations_pca_2             0
# tempartures_lag_1w_pca_1         0
# tempartures_pca_1                0
# tempartures_pca_2                0
# soil_moisture_pca_1              0
# soil_moisture_pca_2              0
# soil_moisture_pca_3              0
# evaporation_lag_1w_pca_1         0
# evaporation_pca_1                0
# soil_composition_pca_1           0
# soil_composition_pca_2           0
# soil_composition_pca_3           0
# soil_composition_pca_4           0
# soil_composition_pca_5           0
# soil_composition_pca_6           0
# soil_composition_pca_7           0
# soil_composition_pca_8           0
# soil_composition_pca_9           0
# station_code                     0
# water_flow_week1                 0
# latitude                         0
# longitude                        0
# catchment                        0
# altitude                         0
# water_flow_lag_1w                0
# water_flow_lag_2w                0
# water_flow_lag_3w                0
# water_flow_lag_4w                0
# water_flow_ma_4w_lag_1w_gauss    0
# water_flow_ma_3w_lag_1w_gauss    0
# water_flow_ma_2w_lag_1w_gauss    0
# water_flow_week2                 0
# water_flow_week3                 0
# water_flow_week4                 0
# north_hemisphere                 0
# snow_index                       0
# month_sin                        0
# month_cos                        0
# season_sin                       0
# season_cos                       0
# region_cluster                   0
# hydro_cluster                    0
# water_flow_evolve_slope          0
# dtype: int64

# %% [markdown]
# ### 4. Hyper parameter tuning
#
# Define the hyperparameter distributions for random search, take care the parameters presented here are choosen so that the search is fast you need to explore wider parameters range.
#
# #### a. Random Search

# %%
cols_to_drop = TO_DROP.copy()
cols_to_drop += ["ObsDate"]
predictor_cols = [col for col in cv_data.columns if col not in cols_to_drop]

preprocessor = ColumnTransformer(transformers=[
    ('select', 'passthrough', predictor_cols),
    ('kbest_select', SelectKBest(score_func=f_regression), predictor_cols)
], remainder='drop')

# %%
import re
N_ITER=35

qrf = {}
final_config = {}
X_incremental = {}
predictions = {}

for i in range(NUMBER_OF_WEEKS):

    print(f"Fitting week {i}")
    station_stats = get_station_stats(
        y_train[i].to_numpy(),
        train_data["station_code"].to_numpy()
    )
    
    scorer = partial(inverted_log_likelihood,
                    cv_data=cv_data,
                    station_stats=station_stats,
                    alpha=ALPHA)
    
    param_distributions = {
        "preprocessor__kbest_select__k": np.arange(3, len(predictor_cols) - 1, 3),
        'model__n_estimators': [5, 15, 35, 55, 85, 100, 130, 150, 190],
        'model__max_depth': [2, 7, 13, 20, 30, 50, 70, 100, 120, 160],
        'model__min_samples_leaf': [9, 15, 25, 35, 50, 60, 80, 105],
        'model__min_samples_split': [9, 15, 25, 35, 50, 60, 80, 105, 125, 150],
        'model__max_features': ['sqrt', 'log2', 0.3, 0.7, None],
        'model__bootstrap': [True, False]
    }

    if i == 0:
        qrf_model= RandomForestQuantileRegressor()

        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('model', qrf_model)
        ])

        random_search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_distributions,
            n_iter=N_ITER,            # Number of parameter settings sampled
            scoring=scorer,       # Use our custom scorer
            cv=cv,                # Our custom spatio-temporal splitter
            n_jobs=-1,             # Use all available cores
            random_state=SEED,
            verbose=3,
            error_score='raise'
        )

        random_search.fit(cv_data, y_train[i])

        best_selector = random_search.best_estimator_.named_steps["preprocessor"].named_transformers_["kbest_select"]
        selected_mask = best_selector.get_support()
        adjusted_data = cv_data.drop(columns=cols_to_drop)
        selected_features = adjusted_data.columns[selected_mask]

        X_incremental[i] = cv_data[selected_features]
        # X_incremental[i] = cv_data
        
        print(random_search.best_params_)

        model_params = {
            key.replace('model__', ''): value
            for key, value in random_search.best_params_.items()
            if key.startswith('model__')
        }

        qrf[i] = RandomForestQuantileRegressor(**model_params)
        qrf[i].fit(X_incremental[i], y_train[i])

        final_config[f"week_{i}_config"] = {}
        final_config[f"week_{i}_config"]["best_params"] = random_search.best_params_
        final_config[f"week_{i}_config"]["best_score"] = random_search.best_score_
        final_config[f"week_{i}_config"]["features_to_train"] = selected_features.tolist()

    else:
        # Use the previous week's predictions as features
        y_pred = qrf[i - 1].predict(X_incremental[i - 1], quantiles=[0.5])
        y_pred = np.reshape(y_pred, (-1, 1))
        
        train_data = cv_data.copy(deep=True)

        train_data[f"week_{i}_pred"] = y_pred
        
        cols_to_add = [
            col for col in X_incremental[i - 1].columns
            if re.match(r"week_\d+_pred", col) or re.match(r"week_\d+_\d+_slope", col)
        ]

        print(f"Adding columns: {cols_to_add}")

        train_data[cols_to_add] = X_incremental[i - 1][cols_to_add]

        if i == 1:
            train_data[f"week_{i-1}_{i}_slope"] = (
                    train_data[f"week_{i}_pred"] - train_data["water_flow_lag_1w"]
                ) / train_data["water_flow_lag_1w"].replace(0, np.nan)
        else:
            train_data[f"week_{i-1}_{i}_slope"] = (
                    train_data[f"week_{i}_pred"] - train_data[f"week_{i-1}_pred"]
                ) / train_data[f"week_{i-1}_pred"].replace(0, np.nan)

        qrf_model= RandomForestQuantileRegressor()

        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('model', qrf_model)
        ])

        random_search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_distributions,
            n_iter=N_ITER  ,            # Number of parameter settings sampled
            scoring=scorer,       # Use our custom scorer
            cv=cv,                # Our custom spatio-temporal splitter
            n_jobs=-1,             # Use all available cores
            random_state=SEED,
            verbose=3,
            error_score='raise'
        )

        random_search.fit(train_data, y_train[i])

        best_selector = random_search.best_estimator_.named_steps["preprocessor"].named_transformers_["kbest_select"]
        selected_mask = best_selector.get_support()
        adjusted_data = cv_data.drop(columns=cols_to_drop)
        selected_features = adjusted_data.columns[selected_mask]

        train_features = selected_features.tolist() + [f"week_{i-1}_{i}_slope", f"week_{i}_pred"] + cols_to_add

        X_incremental[i] = train_data[train_features]
        # X_incremental[i] = train_data
        
        print(random_search.best_params_)

        model_params = {
            key.replace('model__', ''): value
            for key, value in random_search.best_params_.items()
            if key.startswith('model__')
        }

        qrf[i] = RandomForestQuantileRegressor(**model_params)
        qrf[i].fit(X_incremental[i], y_train[i])

        final_config[f"week_{i}_config"] = {}
        final_config[f"week_{i}_config"]["best_params"] = random_search.best_params_
        final_config[f"week_{i}_config"]["best_score"] = random_search.best_score_
        final_config[f"week_{i}_config"]["features_to_train"] = train_features
# Out:
# Fitting week 0
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# {'preprocessor__kbest_select__k': np.int64(39), 'model__n_estimators': 5, 'model__min_samples_split': 15, 'model__min_samples_leaf': 35, 'model__max_features': None, 'model__max_depth': 70, 'model__bootstrap': True}
# Fitting week 1
# Adding columns: []
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# {'preprocessor__kbest_select__k': np.int64(39), 'model__n_estimators': 15, 'model__min_samples_split': 125, 'model__min_samples_leaf': 9, 'model__max_features': None, 'model__max_depth': 70, 'model__bootstrap': False}
# Fitting week 2
# Adding columns: ['week_0_1_slope', 'week_1_pred']
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# {'preprocessor__kbest_select__k': np.int64(18), 'model__n_estimators': 55, 'model__min_samples_split': 25, 'model__min_samples_leaf': 9, 'model__max_features': 0.7, 'model__max_depth': 13, 'model__bootstrap': True}
# Fitting week 3
# Adding columns: ['week_1_2_slope', 'week_2_pred', 'week_0_1_slope', 'week_1_pred']
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# {'preprocessor__kbest_select__k': np.int64(18), 'model__n_estimators': 150, 'model__min_samples_split': 80, 'model__min_samples_leaf': 9, 'model__max_features': None, 'model__max_depth': 100, 'model__bootstrap': True}

# %%
model_params
# Out:
# {'n_estimators': 150,
#  'min_samples_split': 80,
#  'min_samples_leaf': 9,
#  'max_features': None,
#  'max_depth': 100,
#  'bootstrap': True}

# %% [markdown]
# final_config

# %%
final_config
# Out:
# {'week_0_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(39),
#    'model__n_estimators': 5,
#    'model__min_samples_split': 15,
#    'model__min_samples_leaf': 35,
#    'model__max_features': None,
#    'model__max_depth': 70,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.5168132610028775)},
#  'week_1_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(39),
#    'model__n_estimators': 15,
#    'model__min_samples_split': 125,
#    'model__min_samples_leaf': 9,
#    'model__max_features': None,
#    'model__max_depth': 70,
#    'model__bootstrap': False},
#   'best_score': np.float64(-1.3746088939139631),
#   'features_to_train': ['index',
#    'precipitations_lag_1w_pca_1',
#    'precipitations_lag_1w_pca_2',
#    'precipitations_pca_1',
#    'precipitations_pca_2',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_1',
#    'soil_moisture_pca_2',
#    'soil_moisture_pca_3',
#    'evaporation_lag_1w_pca_1',
#    'evaporation_pca_1',
#    'soil_composition_pca_1',
#    'soil_composition_pca_3',
#    'soil_composition_pca_4',
#    'soil_composition_pca_5',
#    'soil_composition_pca_6',
#    'soil_composition_pca_7',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'altitude',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'snow_index',
#    'month_sin',
#    'month_cos',
#    'season_sin',
#    'season_cos',
#    'region_cluster',
#    'hydro_cluster',
#    'week_0_1_slope',
#    'week_1_pred']},
#  'week_2_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(18),
#    'model__n_estimators': 55,
#    'model__min_samples_split': 25,
#    'model__min_samples_leaf': 9,
#    'model__max_features': 0.7,
#    'model__max_depth': 13,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.6994903390320766),
#   'features_to_train': ['index',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_2',
#    'soil_composition_pca_1',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'week_1_2_slope',
#    'week_2_pred',
#    'week_0_1_slope',
#    'week_1_pred']},
#  'week_3_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(18),
#    'model__n_estimators': 150,
#    'model__min_samples_split': 80,
#    'model__min_samples_leaf': 9,
#    'model__max_features': None,
#    'model__max_depth': 100,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.9224695894360717),
#   'features_to_train': ['index',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_2',
#    'soil_composition_pca_1',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'week_2_3_slope',
#    'week_3_pred',
#    'week_1_2_slope',
#    'week_2_pred',
#    'week_0_1_slope',
#    'week_1_pred']}}

# %%
with open(f"search-results/chained_config.json", 'w') as json_file:
    json.dump(final_config, json_file, indent=4, default=str)

# %%
final_config
# Out:
# {'week_0_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(39),
#    'model__n_estimators': 5,
#    'model__min_samples_split': 15,
#    'model__min_samples_leaf': 35,
#    'model__max_features': None,
#    'model__max_depth': 70,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.5168132610028775)},
#  'week_1_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(39),
#    'model__n_estimators': 15,
#    'model__min_samples_split': 125,
#    'model__min_samples_leaf': 9,
#    'model__max_features': None,
#    'model__max_depth': 70,
#    'model__bootstrap': False},
#   'best_score': np.float64(-1.3746088939139631),
#   'features_to_train': ['index',
#    'precipitations_lag_1w_pca_1',
#    'precipitations_lag_1w_pca_2',
#    'precipitations_pca_1',
#    'precipitations_pca_2',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_1',
#    'soil_moisture_pca_2',
#    'soil_moisture_pca_3',
#    'evaporation_lag_1w_pca_1',
#    'evaporation_pca_1',
#    'soil_composition_pca_1',
#    'soil_composition_pca_3',
#    'soil_composition_pca_4',
#    'soil_composition_pca_5',
#    'soil_composition_pca_6',
#    'soil_composition_pca_7',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'altitude',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'snow_index',
#    'month_sin',
#    'month_cos',
#    'season_sin',
#    'season_cos',
#    'region_cluster',
#    'hydro_cluster',
#    'week_0_1_slope',
#    'week_1_pred']},
#  'week_2_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(18),
#    'model__n_estimators': 55,
#    'model__min_samples_split': 25,
#    'model__min_samples_leaf': 9,
#    'model__max_features': 0.7,
#    'model__max_depth': 13,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.6994903390320766),
#   'features_to_train': ['index',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_2',
#    'soil_composition_pca_1',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'week_1_2_slope',
#    'week_2_pred',
#    'week_0_1_slope',
#    'week_1_pred']},
#  'week_3_config': {'best_params': {'preprocessor__kbest_select__k': np.int64(18),
#    'model__n_estimators': 150,
#    'model__min_samples_split': 80,
#    'model__min_samples_leaf': 9,
#    'model__max_features': None,
#    'model__max_depth': 100,
#    'model__bootstrap': True},
#   'best_score': np.float64(-1.9224695894360717),
#   'features_to_train': ['index',
#    'tempartures_lag_1w_pca_1',
#    'tempartures_pca_1',
#    'tempartures_pca_2',
#    'soil_moisture_pca_2',
#    'soil_composition_pca_1',
#    'soil_composition_pca_9',
#    'latitude',
#    'longitude',
#    'catchment',
#    'water_flow_lag_1w',
#    'water_flow_lag_2w',
#    'water_flow_lag_3w',
#    'water_flow_lag_4w',
#    'water_flow_ma_4w_lag_1w_gauss',
#    'water_flow_ma_3w_lag_1w_gauss',
#    'water_flow_ma_2w_lag_1w_gauss',
#    'north_hemisphere',
#    'week_2_3_slope',
#    'week_3_pred',
#    'week_1_2_slope',
#    'week_2_pred',
#    'week_0_1_slope',
#    'week_1_pred']}}

# %%
for i in range(NUMBER_OF_WEEKS):
    print(X_incremental[i])
# Out:
#        index  precipitations_lag_1w_pca_1  precipitations_lag_1w_pca_2  \
# 0          0                    -0.107253                     0.002576
# 1          1                    -0.060369                     0.010880
# 2          2                     0.127174                     0.003266
# 3          3                    -0.046789                    -0.010902
# 4          4                    -0.027139                    -0.008927
# ...      ...                          ...                          ...
# 27697  27697                    -0.111365                    -0.010386
# 27698  27698                     0.423123                     0.158037
# 27699  27699                    -0.094716                     0.011494
# 27700  27700                    -0.083629                    -0.002477
# 27701  27701                     0.425137                    -0.004625
#
#        precipitations_pca_1  precipitations_pca_2  tempartures_lag_1w_pca_1  \
# 0                 -0.024713              0.006300                 -0.538810
# 1                  0.054113              0.001283                 -0.563840
# 2                 -0.021363             -0.005599                 -0.397161
# 3                 -0.012818             -0.004777                 -0.376517
# 4                  0.158883              0.006354                 -0.253852
# ...                     ...                   ...                       ...
# 27697              0.196274              0.080746                  0.628182
# 27698             -0.039283              0.006403                  0.583803
# 27699             -0.036087             -0.000865                  0.627073
# 27700              0.179770             -0.004120                  0.616189
# 27701              0.051901             -0.003007                  0.520875
#
#        tempartures_pca_1  tempartures_pca_2  soil_moisture_pca_1  \
# 0              -0.531157           0.127798             0.168692
# 1              -0.366071           0.104746             0.202910
# 2              -0.345322           0.104179             0.249127
# 3              -0.223412           0.090472             0.180665
# 4              -0.203445           0.081657             0.261371
# ...                  ...                ...                  ...
# 27697           0.605592          -0.030097            -0.032841
# 27698           0.648356          -0.036785             0.133550
# 27699           0.637397          -0.036664            -0.181128
# 27700           0.543229          -0.021681             0.207891
# 27701           0.589288          -0.027416             0.388167
#
#        soil_moisture_pca_2  ...  water_flow_ma_3w_lag_1w_gauss  \
# 0                 0.012413  ...                      78.746370
# 1                 0.000366  ...                       8.929524
# 2                -0.008760  ...                       8.804762
# 3                -0.021263  ...                       8.794762
# 4                 0.006201  ...                       9.420476
# ...                    ...  ...                            ...
# 27697             0.165029  ...                     456.091976
# 27698             0.185253  ...                     445.488838
# 27699             0.167546  ...                     783.227629
# 27700             0.151575  ...                     818.865676
# 27701             0.137378  ...                     887.100486
#
#        water_flow_ma_2w_lag_1w_gauss  north_hemisphere  snow_index  \
# 0                           9.319286               1.0    0.014210
# 1                           9.110714               1.0    0.047728
# 2                           8.171429               1.0    0.016580
# 3                           9.117143               1.0    0.018808
# 4                          10.034286               1.0    0.084016
# ...                              ...               ...         ...
# 27697                     464.509443               0.0    0.004081
# 27698                     462.085421               0.0    0.000291
# 27699                     916.479836               0.0    0.000451
# 27700                    1024.574700               0.0    0.004732
# 27701                     617.894707               0.0    0.002068
#
#           month_sin  month_cos  season_sin    season_cos  region_cluster  \
# 0      5.000000e-01   0.866025         1.0  6.123234e-17               7
# 1      5.000000e-01   0.866025         1.0  6.123234e-17               7
# 2      8.660254e-01   0.500000         1.0  6.123234e-17               7
# 3      8.660254e-01   0.500000         1.0  6.123234e-17               7
# 4      8.660254e-01   0.500000         1.0  6.123234e-17               7
# ...             ...        ...         ...           ...             ...
# 27697 -2.449294e-16   1.000000        -1.0 -1.836970e-16               3
# 27698 -2.449294e-16   1.000000        -1.0 -1.836970e-16               3
# 27699 -2.449294e-16   1.000000        -1.0 -1.836970e-16               3
# 27700 -2.449294e-16   1.000000        -1.0 -1.836970e-16               3
# 27701  5.000000e-01   0.866025        -1.0 -1.836970e-16               3
#
#        hydro_cluster
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 27697              3
# 27698              3
# 27699              1
# 27700              9
# 27701              3
#
# [27702 rows x 39 columns]
#        index  precipitations_lag_1w_pca_1  precipitations_lag_1w_pca_2  \
# 0          0                    -0.107253                     0.002576
# 1          1                    -0.060369                     0.010880
# 2          2                     0.127174                     0.003266
# 3          3                    -0.046789                    -0.010902
# 4          4                    -0.027139                    -0.008927
# ...      ...                          ...                          ...
# 27697  27697                    -0.111365                    -0.010386
# 27698  27698                     0.423123                     0.158037
# 27699  27699                    -0.094716                     0.011494
# 27700  27700                    -0.083629                    -0.002477
# 27701  27701                     0.425137                    -0.004625
#
#        precipitations_pca_1  precipitations_pca_2  tempartures_lag_1w_pca_1  \
# 0                 -0.024713              0.006300                 -0.538810
# 1                  0.054113              0.001283                 -0.563840
# 2                 -0.021363             -0.005599                 -0.397161
# 3                 -0.012818             -0.004777                 -0.376517
# 4                  0.158883              0.006354                 -0.253852
# ...                     ...                   ...                       ...
# 27697              0.196274              0.080746                  0.628182
# 27698             -0.039283              0.006403                  0.583803
# 27699             -0.036087             -0.000865                  0.627073
# 27700              0.179770             -0.004120                  0.616189
# 27701              0.051901             -0.003007                  0.520875
#
#        tempartures_pca_1  tempartures_pca_2  soil_moisture_pca_1  \
# 0              -0.531157           0.127798             0.168692
# 1              -0.366071           0.104746             0.202910
# 2              -0.345322           0.104179             0.249127
# 3              -0.223412           0.090472             0.180665
# 4              -0.203445           0.081657             0.261371
# ...                  ...                ...                  ...
# 27697           0.605592          -0.030097            -0.032841
# 27698           0.648356          -0.036785             0.133550
# 27699           0.637397          -0.036664            -0.181128
# 27700           0.543229          -0.021681             0.207891
# 27701           0.589288          -0.027416             0.388167
#
#        soil_moisture_pca_2  ...  north_hemisphere  snow_index     month_sin  \
# 0                 0.012413  ...               1.0    0.014210  5.000000e-01
# 1                 0.000366  ...               1.0    0.047728  5.000000e-01
# 2                -0.008760  ...               1.0    0.016580  8.660254e-01
# 3                -0.021263  ...               1.0    0.018808  8.660254e-01
# 4                 0.006201  ...               1.0    0.084016  8.660254e-01
# ...                    ...  ...               ...         ...           ...
# 27697             0.165029  ...               0.0    0.004081 -2.449294e-16
# 27698             0.185253  ...               0.0    0.000291 -2.449294e-16
# 27699             0.167546  ...               0.0    0.000451 -2.449294e-16
# 27700             0.151575  ...               0.0    0.004732 -2.449294e-16
# 27701             0.137378  ...               0.0    0.002068  5.000000e-01
#
#        month_cos  season_sin    season_cos  region_cluster  hydro_cluster  \
# 0       0.866025         1.0  6.123234e-17               7              4
# 1       0.866025         1.0  6.123234e-17               7              4
# 2       0.500000         1.0  6.123234e-17               7              4
# 3       0.500000         1.0  6.123234e-17               7              4
# 4       0.500000         1.0  6.123234e-17               7              4
# ...          ...         ...           ...             ...            ...
# 27697   1.000000        -1.0 -1.836970e-16               3              3
# 27698   1.000000        -1.0 -1.836970e-16               3              3
# 27699   1.000000        -1.0 -1.836970e-16               3              1
# 27700   1.000000        -1.0 -1.836970e-16               3              9
# 27701   0.866025        -1.0 -1.836970e-16               3              3
#
#        week_0_1_slope  week_1_pred
# 0           -0.168227     8.377143
# 1            0.652792    13.470257
# 2           -0.115432     7.247143
# 3           -0.165742     8.377143
# 4            0.665764    16.702857
# ...               ...          ...
# 27697        0.164914   601.938343
# 27698       -0.019105   399.663486
# 27699       -0.116929  1258.828671
# 27700       -0.034794   601.938343
# 27701        0.269764   777.288771
#
# [27702 rows x 41 columns]
#        index  tempartures_lag_1w_pca_1  tempartures_pca_1  tempartures_pca_2  \
# 0          0                 -0.538810          -0.531157           0.127798
# 1          1                 -0.563840          -0.366071           0.104746
# 2          2                 -0.397161          -0.345322           0.104179
# 3          3                 -0.376517          -0.223412           0.090472
# 4          4                 -0.253852          -0.203445           0.081657
# ...      ...                       ...                ...                ...
# 27697  27697                  0.628182           0.605592          -0.030097
# 27698  27698                  0.583803           0.648356          -0.036785
# 27699  27699                  0.627073           0.637397          -0.036664
# 27700  27700                  0.616189           0.543229          -0.021681
# 27701  27701                  0.520875           0.589288          -0.027416
#
#        soil_moisture_pca_2  soil_composition_pca_1  soil_composition_pca_9  \
# 0                 0.012413                0.954040                0.128098
# 1                 0.000366                0.954040                0.128098
# 2                -0.008760                0.954040                0.128098
# 3                -0.021263                0.954040                0.128098
# 4                 0.006201                0.954040                0.128098
# ...                    ...                     ...                     ...
# 27697             0.165029               -2.798534               -1.132140
# 27698             0.185253               -2.798534               -1.132140
# 27699             0.167546               -2.798534               -1.132140
# 27700             0.151575               -2.798534               -1.132140
# 27701             0.137378               -2.798534               -1.132140
#
#        latitude  longitude  catchment  ...  water_flow_lag_3w  \
# 0      0.932117   0.854251   0.005945  ...           0.014058
# 1      0.932117   0.854251   0.005945  ...           0.001529
# 2      0.932117   0.854251   0.005945  ...           0.001797
# 3      0.932117   0.854251   0.005945  ...           0.001454
# 4      0.932117   0.854251   0.005945  ...           0.001462
# ...         ...        ...        ...  ...                ...
# 27697  0.009376   0.051031   1.000000  ...           0.078384
# 27698  0.009376   0.051031   1.000000  ...           0.073573
# 27699  0.009376   0.051031   1.000000  ...           0.092208
# 27700  0.009376   0.051031   1.000000  ...           0.072708
# 27701  0.009376   0.051031   1.000000  ...           0.254379
#
#        water_flow_lag_4w  water_flow_ma_4w_lag_1w_gauss  \
# 0               0.014048                      78.747445
# 1               0.014048                      78.747445
# 2               0.001529                       8.745357
# 3               0.001797                       9.113929
# 4               0.001454                       9.102857
# ...                  ...                            ...
# 27697           0.074752                     446.794764
# 27698           0.078384                     443.930889
# 27699           0.073573                     690.494639
# 27700           0.092208                     743.330061
# 27701           0.072708                     767.187271
#
#        water_flow_ma_3w_lag_1w_gauss  water_flow_ma_2w_lag_1w_gauss  \
# 0                          78.746370                       9.319286
# 1                           8.929524                       9.110714
# 2                           8.804762                       8.171429
# 3                           8.794762                       9.117143
# 4                           9.420476                      10.034286
# ...                              ...                            ...
# 27697                     456.091976                     464.509443
# 27698                     445.488838                     462.085421
# 27699                     783.227629                     916.479836
# 27700                     818.865676                    1024.574700
# 27701                     887.100486                     617.894707
#
#        north_hemisphere  week_1_2_slope  week_2_pred  week_0_1_slope  \
# 0                   1.0        0.427183    11.955714       -0.168227
# 1                   1.0        0.324611    17.842857        0.652792
# 2                   1.0        0.214863     8.804286       -0.115432
# 3                   1.0        0.132503     9.487143       -0.165742
# 4                   1.0        0.068252    17.842857        0.665764
# ...                 ...             ...          ...             ...
# 27697               0.0        0.761199  1060.132971        0.164914
# 27698               0.0       -0.076014   369.283614       -0.019105
# 27699               0.0       -0.266874   922.879700       -0.116929
# 27700               0.0        0.962825  1181.499900       -0.034794
# 27701               0.0       -0.135509   671.959043        0.269764
#
#        week_1_pred
# 0         8.377143
# 1        13.470257
# 2         7.247143
# 3         8.377143
# 4        16.702857
# ...            ...
# 27697   601.938343
# 27698   399.663486
# 27699  1258.828671
# 27700   601.938343
# 27701   777.288771
#
# [27702 rows x 22 columns]
#        index  tempartures_lag_1w_pca_1  tempartures_pca_1  tempartures_pca_2  \
# 0          0                 -0.538810          -0.531157           0.127798
# 1          1                 -0.563840          -0.366071           0.104746
# 2          2                 -0.397161          -0.345322           0.104179
# 3          3                 -0.376517          -0.223412           0.090472
# 4          4                 -0.253852          -0.203445           0.081657
# ...      ...                       ...                ...                ...
# 27697  27697                  0.628182           0.605592          -0.030097
# 27698  27698                  0.583803           0.648356          -0.036785
# 27699  27699                  0.627073           0.637397          -0.036664
# 27700  27700                  0.616189           0.543229          -0.021681
# 27701  27701                  0.520875           0.589288          -0.027416
#
#        soil_moisture_pca_2  soil_composition_pca_1  soil_composition_pca_9  \
# 0                 0.012413                0.954040                0.128098
# 1                 0.000366                0.954040                0.128098
# 2                -0.008760                0.954040                0.128098
# 3                -0.021263                0.954040                0.128098
# 4                 0.006201                0.954040                0.128098
# ...                    ...                     ...                     ...
# 27697             0.165029               -2.798534               -1.132140
# 27698             0.185253               -2.798534               -1.132140
# 27699             0.167546               -2.798534               -1.132140
# 27700             0.151575               -2.798534               -1.132140
# 27701             0.137378               -2.798534               -1.132140
#
#        latitude  longitude  catchment  ...  water_flow_ma_4w_lag_1w_gauss  \
# 0      0.932117   0.854251   0.005945  ...                      78.747445
# 1      0.932117   0.854251   0.005945  ...                      78.747445
# 2      0.932117   0.854251   0.005945  ...                       8.745357
# 3      0.932117   0.854251   0.005945  ...                       9.113929
# 4      0.932117   0.854251   0.005945  ...                       9.102857
# ...         ...        ...        ...  ...                            ...
# 27697  0.009376   0.051031   1.000000  ...                     446.794764
# 27698  0.009376   0.051031   1.000000  ...                     443.930889
# 27699  0.009376   0.051031   1.000000  ...                     690.494639
# 27700  0.009376   0.051031   1.000000  ...                     743.330061
# 27701  0.009376   0.051031   1.000000  ...                     767.187271
#
#        water_flow_ma_3w_lag_1w_gauss  water_flow_ma_2w_lag_1w_gauss  \
# 0                          78.746370                       9.319286
# 1                           8.929524                       9.110714
# 2                           8.804762                       8.171429
# 3                           8.794762                       9.117143
# 4                           9.420476                      10.034286
# ...                              ...                            ...
# 27697                     456.091976                     464.509443
# 27698                     445.488838                     462.085421
# 27699                     783.227629                     916.479836
# 27700                     818.865676                    1024.574700
# 27701                     887.100486                     617.894707
#
#        north_hemisphere  week_2_3_slope  week_3_pred  week_1_2_slope  \
# 0                   1.0        0.035966    12.385714        0.427183
# 1                   1.0        0.164131    20.771429        0.324611
# 2                   1.0        0.394938    12.281429        0.214863
# 3                   1.0        0.305526    12.385714        0.132503
# 4                   1.0       -0.059247    16.785714        0.068252
# ...                 ...             ...          ...             ...
# 27697               0.0       -0.204877   842.936629        0.761199
# 27698               0.0        0.232879   455.282014       -0.076014
# 27699               0.0       -0.120977   811.232271       -0.266874
# 27700               0.0       -0.161184   991.060971        0.962825
# 27701               0.0       -0.154330   568.255586       -0.135509
#
#        week_2_pred  week_0_1_slope  week_1_pred
# 0        11.955714       -0.168227     8.377143
# 1        17.842857        0.652792    13.470257
# 2         8.804286       -0.115432     7.247143
# 3         9.487143       -0.165742     8.377143
# 4        17.842857        0.665764    16.702857
# ...            ...             ...          ...
# 27697  1060.132971        0.164914   601.938343
# 27698   369.283614       -0.019105   399.663486
# 27699   922.879700       -0.116929  1258.828671
# 27700  1181.499900       -0.034794   601.938343
# 27701   671.959043        0.269764   777.288771
#
# [27702 rows x 24 columns]
